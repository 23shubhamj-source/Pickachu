# %%
print("                  Age Calculator")
name= input(" What is your name?\n")
print("Nice to meet you",name.upper(),"!")

Birthoo_year = input("What is your birth year?\n")
Birth_year= int(Birthoo_year)

Current_year = 2026
Age = Current_year - Birth_year
print("You are approximately",Age, "years old.")

# %%
print("           Driving-Eligibility Portal")
age=int(input("What is your age?\n")) # Escape sequence character
print("Your age is", age,".")
if(age>18):
    print("Congratulations! you can apply for driving license.")    # indentation 
    print("Note: If you a senior citizen then you have to give some extra medical tests.")
else:
    print("Sorry! there is still time for your eligibilty fulfilment to get your driving license.")
